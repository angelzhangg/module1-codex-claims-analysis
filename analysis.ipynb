# %% [markdown]
# <a href="https://colab.research.google.com/github/angelzhangg/module1-codex-claims-analysis/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv')

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep='|')
# Out:
# <ipython-input-43-aafb7dcbe53a>:1: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep='|')

# %%
df
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0     -10000010254618 -10000930037831                          V
# 1     -10000010254653 -10000930038030                          V
# 2     -10000010254653 -10000930038031                          V
# 3     -10000010254656 -10000930038162                          V
# 4     -10000010254656 -10000930038162                          V
# ...               ...             ...                        ...
# 58061 -10000010288008 -10000931485965                          V
# 58062 -10000010288008 -10000931485967                          V
# 58063 -10000010288008 -10000931485969                          V
# 58064 -10000010288008 -10000931485971                          V
# 58065 -10000010288010 -10000931486024                          V
#
#        NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                   60  25-Mar-2015  25-Mar-2015      27-Mar-2015
# ...

# %%
#### list all the columns
df.columns
# Out:
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'FI_CLM_PROC_DT',
#        'CLAIM_QUERY_CODE', 'PRVDR_NUM',
#        ...
#        'PRCDR_DT24', 'ICD_PRCDR_CD25', 'PRCDR_DT25', 'IME_OP_CLM_VAL_AMT',
#        'DSH_OP_CLM_VAL_AMT', 'CLM_UNCOMPD_CARE_PMT_AMT', 'CLM_LINE_NUM',
#        'REV_CNTR', 'HCPCS_CD', 'REV_CNTR_DDCTBL_COINSRNC_CD'],
#       dtype='object', length=197)

# %%
for index in df.columns:
    print(index)
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
# 1. value count of claim principal diagnosis code
df['PRNCPAL_DGNS_CD'].value_counts()
# Out:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64

# %%
# 2. frequency of Healthcare Common Procedure Coding System
df.HCPCS_CD.value_counts()
# Out:
# HCPCS_CD
# 99221    8298
# G0444    7990
# 96156    5080
# 99408    4196
# 99495    3867
#          ...
# S9361       1
# S9355       1
# S9374       1
# S9377       1
# G9829       1
# Name: count, Length: 106, dtype: int64

# %%
# 3. frequency of ICD Diagnosis Code
df.ICD_DGNS_CD16.value_counts()
# Out:
# ICD_DGNS_CD16
# E8881      2826
# E669       2719
# E1121      2233
# R7303      2102
# I259       1835
#            ...
# G309          1
# T7412X        1
# E113592       1
# I370          1
# J441          1
# Name: count, Length: 157, dtype: int64

# %%
# 4. frequency of second POA indicator for a claim
df.CLM_POA_IND_SW2.value_counts()
# Out:
# CLM_POA_IND_SW2
# Y    45106
# N    12903
# Name: count, dtype: int64

# %%
# 5. frequency of fourth ICD Diagnosis code
df.ICD_DGNS_CD4.value_counts()
# Out:
# ICD_DGNS_CD4
# N1830     4203
# Z608      3359
# I259      2715
# Z653      2501
# Z733      2354
#           ...
# R062         1
# R509         1
# I25110       1
# I501         1
# F1021        1
# Name: count, Length: 223, dtype: int64

# %%
# 6. frequency of Claim Procedure Code
df.ICD_PRCDR_CD21.value_counts()
# Out:
# ICD_PRCDR_CD21
# F08H5ZZ    149
# Z9981       71
# F13         46
# Z8616       24
# Name: count, dtype: int64

# %%
# 7. frequency of Claim Procedure Code
df.PRCDR_DT15.value_counts()
# Out:
# PRCDR_DT15
# 16-Nov-2020    46
# 26-Nov-2020    46
# 29-Dec-2020    39
# 02-Jul-2022    34
# 23-Jun-2022    34
#                ..
# 29-Jul-2020    15
# 05-Nov-2020    15
# 08-Jan-2021    15
# 24-Jan-2021    15
# 07-Aug-2021    14
# Name: count, Length: 78, dtype: int64

# %%
# 8. frequency of Claim Procedure Code
df.ICD_PRCDR_CD18.value_counts()
# Out:
# ICD_PRCDR_CD18
# F08H5ZZ    229
# Z9981       49
# Z8616       46
# F13         46
# Name: count, dtype: int64
